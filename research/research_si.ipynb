# %%
import os

import warnings
warnings.filterwarnings("ignore")

# %%
os.chdir("../")
# %pwd
# Out:
# '/home/ubuntu/ContinuousMathematicalModelling'

# %%
from src.config.configuration import ConfigurationManager
from src.components.optimizator import Optimizator

# %%
manager = ConfigurationManager()
configs = manager.get_optimizator_config()
optimizator = Optimizator(configs, 
                          constraints=manager.params[configs.model_name]['constraints'],
                          plot_default_params=manager.config.plots_default_params)
# Out:
# [2023-12-23 14:57:35,922: 40: logger: INFO: common:  yaml file: src/config/config.yaml loaded successfully]
# [2023-12-23 14:57:35,926: 40: logger: INFO: common:  yaml file: src/params.yaml loaded successfully]

# %%
df = optimizator.read_data()

# %% [markdown]
# # Germany

# %%
# %%time
optimizator.run_stage(df, 'Germany')
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# {
#     "train_based": {
#         "mean_absolute_percentage_error_TRAIN": 0.8332224503721957,
#         "mean_absolute_percentage_error_VAL": 1.4251033058878557,
#         "params": {
#             "b": 0.02032872424251013
#         }
#     },
#     "val_based": {
#         "mean_absolute_percentage_error_TRAIN": 0.9859592020755621,
#         "mean_absolute_percentage_error_VAL": 0.9887601880125824,
#         "params": {
#             "b": 0.0
#         }
#     }
# }
# [2023-12-23 14:57:45,054: 85: logger: INFO: common:  json file saved at: results/SI/Germany.json]
# CPU times: user 8.47 s, sys: 632 ms, total: 9.1 s
# Wall time: 8.72 s

# %% [markdown]
# # Russia

# %%
# %%time
optimizator.run_stage(df, 'Russia')
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# {
#     "train_based": {
#         "mean_absolute_percentage_error_TRAIN": 0.8506510062527104,
#         "mean_absolute_percentage_error_VAL": 1.528728298702186,
#         "params": {
#             "b": 0.02303389004713153
#         }
#     },
#     "val_based": {
#         "mean_absolute_percentage_error_TRAIN": 0.9923086240974403,
#         "mean_absolute_percentage_error_VAL": 0.9938470149653114,
#         "params": {
#             "b": 0.0
#         }
#     }
# }
# [2023-12-23 14:58:35,873: 85: logger: INFO: common:  json file saved at: results/SI/Russia.json]
# CPU times: user 8.66 s, sys: 407 ms, total: 9.07 s
# Wall time: 8.63 s

# %% [markdown]
# # Italy

# %%
# %%time
optimizator.run_stage(df, 'Italy')
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# {
#     "train_based": {
#         "mean_absolute_percentage_error_TRAIN": 0.8467448217883115,
#         "mean_absolute_percentage_error_VAL": 1.4827981507888564,
#         "params": {
#             "b": 0.020966468839933187
#         }
#     },
#     "val_based": {
#         "mean_absolute_percentage_error_TRAIN": 0.9937881906082272,
#         "mean_absolute_percentage_error_VAL": 0.9950305665099755,
#         "params": {
#             "b": 0.0
#         }
#     }
# }
# [2023-12-23 14:58:58,414: 85: logger: INFO: common:  json file saved at: results/SI/Italy.json]
# CPU times: user 8.86 s, sys: 427 ms, total: 9.29 s
# Wall time: 8.85 s

# %% [markdown]
# # United Kingdom

# %%
# %%time
optimizator.run_stage(df, 'United Kingdom')
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# {
#     "train_based": {
#         "mean_absolute_percentage_error_TRAIN": 0.8387381423509706,
#         "mean_absolute_percentage_error_VAL": 1.1461014907298148,
#         "params": {
#             "b": 0.022493934330048954
#         }
#     },
#     "val_based": {
#         "mean_absolute_percentage_error_TRAIN": 0.9921615001312177,
#         "mean_absolute_percentage_error_VAL": 0.9937294576368623,
#         "params": {
#             "b": 0.0
#         }
#     }
# }
# [2023-12-23 14:59:08,265: 85: logger: INFO: common:  json file saved at: results/SI/United Kingdom.json]
# CPU times: user 8.53 s, sys: 612 ms, total: 9.14 s
# Wall time: 8.7 s
